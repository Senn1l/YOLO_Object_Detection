# %% [markdown]
# Họ tên: Phan Đặng Anh Khôi <br>
# MSSV: 21127325 <br>
# Project: YOLO object detection application for vehicle/traffic

# %% [markdown]
# # 0/ Cấp quyền truy cập

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # 1/ Tải mã nguồn

# %%
# Duy nhất 1 lần
# %cd /content/gdrive/My\ Drive/Colab\ Notebooks
# !rm -rf yolov7
# !git clone https://github.com/WongKinYiu/yolov7

# %% [markdown]
# # 2/ Thực hiện chuẩn bị dữ liệu
# - Dữ liệu được lấy từ roboflow theo link: https://universe.roboflow.com/ilham-winar/venom/dataset/8 và tải theo format YOLOv7.
# - Sau khi tải zip, ta sẽ có được 3 folder là train, valid và test và một file data.yaml, thực hiện kéo và thả file data.yaml vào folder data (đổi tên nếu muốn).
# - Sau đó thực hiện upload 3 folder train, valid và test vào folder data. (sử dụng google drive for desktop sẽ nhanh hơn)

# %% [markdown]
# # 3/ Tải thư viện theo requirements

# %%
# Khởi động lại phiên sau khi tải requirements
# %cd /content/gdrive/My\ Drive/Colab\ Notebooks/YOLO_Project_StatisticsLearning/yolov7
# !pip install -r requirements.txt
# Out:
# /content/gdrive/My Drive/Colab Notebooks/YOLO_Project_StatisticsLearning/yolov7
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %% [markdown]
# # 4/ Huấn luyện mô hình

# %% [markdown]
# - Đầu tiên tinh chỉnh tham số theo mô hình của mình.
# - cfg: config file -> duplicate file yolov7-tiny.yaml trong training và chỉnh số class thành 12.
# - weights: file trọng số đã được huấn luyện (pretrained) hoặc tiếp tục huấn luyện <br>
# Link bộ trọng số đã được huấn luyện trước trong link github: https://github.com/WongKinYiu/yolov7?tab=readme-ov-file, Transfer learning, file yolov7_training.pt và đặt chung với file train.py
# - name: tên của phiên chạy (huấn luyện)
# - hyp: siêu tham số

# %%
# %cd /content/gdrive/My\ Drive/Colab\ Notebooks/YOLO_Project_StatisticsLearning/yolov7
# finetune p5 models
#!python train.py --workers 8 --device 0 --batch-size 32 --data data/custom.yaml --img 640 640 --cfg cfg/training/yolov7-custom.yaml --weights 'yolov7_training.pt' --name yolov7-custom --hyp data/hyp.scratch.custom.yaml
# finetune p6 models
#!python train_aux.py --workers 8 --device 0 --batch-size 16 --data data/custom.yaml --img 1280 1280 --cfg cfg/training/yolov7-w6-custom.yaml --weights 'yolov7-w6_training.pt' --name yolov7-w6-custom --hyp data/hyp.scratch.custom.yaml

# Thực hiện huấn luyện sử dụng GPU (cuda) - id device = 0
# !python train.py --workers 8 --device 0 --batch-size 64 --data data/carsData.yaml --img 640 640 --cfg cfg/training/yolov7-tiny-custom.yaml --weights 'yolov7_51-100.pt' --name yolov7-custom --hyp data/hyp.scratch.custom.yaml --epochs 50
# Out:
# /content/gdrive/My Drive/Colab Notebooks/yolov7
# 2024-08-12 04:55:02.193978: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-12 04:55:02.213624: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-12 04:55:02.219974: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-08-12 04:55:02.234781: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# ...

# %% [markdown]
# # 5/ Kiểm tra mô hình (Testing)

# %%
# %cd /content/gdrive/My\ Drive/Colab\ Notebooks/YOLO_Project_StatisticsLearning/yolov7
# data: data path (.yaml)
# img: img-size
# conf: conf-threshold, ngưỡng cho confidence score
# iou: iou-threshold for Non-maximum supression
# device: device id - 0 (CUDA), hay cpu
# weights: bộ trọng số đã được huấn luyện
# name: tên của phiên chạy
# !python test.py --data data/carsData.yaml --img 640 --batch 64 --conf 0.001 --iou 0.65 --device cpu --weights "./runs/train/yolov7-custom3/weights/best.pt" --name "yolov7_valid_best"
# Out:
# /content/gdrive/My Drive/Colab Notebooks/yolov7
# Namespace(weights=['./runs/train/yolov7-custom3/weights/best.pt'], data='data/carsData.yaml', batch_size=64, img_size=640, conf_thres=0.001, iou_thres=0.65, task='val', device='cpu', single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project='runs/test', name='yolov7_valid_best', exist_ok=False, no_trace=False, v5_metric=False)
# YOLOR 🚀 2024-8-10 torch 2.3.1+cu121 CPU
#
# Fusing layers...
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 208 layers, 6037362 parameters, 0 gradients, 13.1 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
# ...

# %% [markdown]
# # 6/ Dự đoán (Inference)

# %%
# %cd /content/gdrive/My\ Drive/Colab\ Notebooks/YOLO_Project_StatisticsLearning/yolov7
# weights: bộ trọng số đã được huấn luyện
# conf: conf-threshold, ngưỡng cho confidence score
# img-size: size ảnh 640x640
# source: ảnh dùng để detect
# !python detect.py --weights "./runs/train/yolov7-custom3/weights/best.pt" --conf 0.25 --img-size 640 --source inference/vehicleImages/testVehicle2.jpg
# Out:
# /content/gdrive/My Drive/Colab Notebooks/YOLO_Project_StatisticsLearning/yolov7
# Namespace(weights=['./runs/train/yolov7-custom3/weights/best.pt'], source='inference/vehicleImages/testVehicle2.jpg', img_size=640, conf_thres=0.25, iou_thres=0.45, device='', view_img=False, save_txt=False, save_conf=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, no_trace=False)
# YOLOR 🚀 2024-8-10 torch 2.3.1+cu121 CPU
#
# Fusing layers...
# IDetect.fuse
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 208 layers, 6037362 parameters, 0 gradients, 13.1 GFLOPS
#  Convert model to Traced-model...
#  traced_script_module saved!
# ...
